# %%
from src.pipelines.index import run_indexing
run_indexing()
# Out:
# Fetching 30 files:   0%|          | 0/30 [00:00<?, ?it/s]
# INFO:FlagEmbedding.finetune.embedder.encoder_only.m3.runner:loading existing colbert_linear and sparse_linear---------
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# INFO:httpx:HTTP Request: GET http://localhost:6333 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: DELETE http://localhost:6333/collections/foreign_guide "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: PUT http://localhost:6333/collections/foreign_guide "HTTP/1.1 200 OK"
# INFO:src.pipelines.index:Collection ready: foreign_guide
# INFO:src.pipelines.index:Loaded 101 docs
# ...
# Indexing: 100%|██████████| 4/4 [00:21<00:00,  5.46s/it]
# INFO:httpx:HTTP Request: POST http://localhost:6333/collections/foreign_guide/points/count "HTTP/1.1 200 OK"
# ...

# %%
import sys, os
sys.path.append(os.path.abspath(os.getcwd()))

from src.rag.answer import generate_answer

res, docs = generate_answer("How can I extend my student (D-2) visa?")
print(res.content)
# Out:
# INFO:httpx:HTTP Request: GET http://localhost:6333 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:6333/collections/foreign_guide/points/search "HTTP/1.1 200 OK"
# You're using a XLMRobertaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ```json
# {
#   "steps": [
#     {
#       "step": 1,
#       "title": "Check Eligibility",
#       "en": "Ensure you are eligible for an extension of your D-2 student visa. You must be enrolled in a recognized educational institution and your current visa must not have expired.",
#       "ko": "D-2 학생 비자 연장 자격을 확인하세요. 인정된 교육 기관에 등록되어 있어야 하며 현재 비자가 만료되지 않아야 합니다."
#     },
#     {
#       "step": 2,
#       "title": "Gather Required Documents",
# ...

# %%
from src.rag.evaluate import  run_evel
df = run_evel()
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# INFO:httpx:HTTP Request: GET http://localhost:6333 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:6333/collections/foreign_guide/points/search "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET http://localhost:6333 "HTTP/1.1 200 OK"
# ...

# %%
df.tail()
# Out:
#                                             user_input  \
# 122       How to get official tourist maps and guides?
# 123            How to find recycling centers in Seoul?
# 124  How to enroll in Korean language programs offe...
# 125       How to find legal counseling for foreigners?
# 126  How to get public transportation fare info for...
#
#                                     retrieved_contexts  \
# 122  [Skip to Content\n 이 누리집은 대한민국 공식 전자정부 누리집입니다....
# 123  [02 RESIDENCE\nl 27\nGuidebook for Living in S...
# 124  [l 11\nGuidebook for Living in Seoul 10\n01 LE...
# 125  [l 77\nGuidebook for Living in Seoul 76\n06 WO...
# 126  [l 39\nGuidebook for Living in Seoul 38\n03 TR...
#
#                                               response  \
# 122  ```json\n{\n  "steps": [\n    {\n      "step":...
# 123  ```json\n{\n  "steps": [\n    {\n      "step":...
# 124  ```json\n{\n  "steps": [\n    {\n      "step":...
# 125  ```json\n{\n  "steps": [\n    {\n      "step":...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_input          127 non-null    object
#  1   retrieved_contexts  127 non-null    object
#  2   response            127 non-null    object
#  3   reference           127 non-null    object
#  4   context_precision   125 non-null    float64
#  5   context_recall      108 non-null    float64
#  6   answer_relevancy    127 non-null    float64
#  7   faithfulness        106 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 8.1+ KB

# %%
df.isna().sum()
# Out:
# user_input             0
# retrieved_contexts     0
# response               0
# reference              0
# context_precision      2
# context_recall        19
# answer_relevancy       0
# faithfulness          21
# dtype: int64
