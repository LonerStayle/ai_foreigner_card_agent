# %%
import pandas as pd 

raw_df = pd.read_csv('rag_eval_results.csv')
df = raw_df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_input          127 non-null    object
#  1   retrieved_contexts  127 non-null    object
#  2   response            127 non-null    object
#  3   reference           127 non-null    object
#  4   context_precision   125 non-null    float64
#  5   context_recall      108 non-null    float64
#  6   answer_relevancy    127 non-null    float64
#  7   faithfulness        106 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 8.1+ KB

# %%
df.isna().sum()
# Out:
# user_input             0
# retrieved_contexts     0
# response               0
# reference              0
# context_precision      2
# context_recall        19
# answer_relevancy       0
# faithfulness          21
# dtype: int64

# %%
df_clean = df.dropna()
df_clean.describe()
# Out:
#        context_precision  context_recall  answer_relevancy  faithfulness
# count          91.000000       91.000000         91.000000     91.000000
# mean            0.500253        0.641889          0.892216      0.519281
# std             0.411950        0.367668          0.108242      0.388874
# min             0.000000        0.000000          0.000000      0.000000
# 25%             0.000000        0.333333          0.861717      0.133333
# 50%             0.531746        0.750000          0.910243      0.500000
# 75%             0.932540        1.000000          0.944583      0.958333
# max             1.000000        1.000000          0.983198      1.000000

# %%
import matplotlib.pyplot as plt
import seaborn
plt.figure(figsize=(20, 10))
seaborn.boxplot(data = df, y = 'context_precision')
# Out:
# <Axes: ylabel='context_precision'>
